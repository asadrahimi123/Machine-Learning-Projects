# %%
import numpy as np
import pandas as pd

# %%
std = pd.read_csv('D:/ai/numpy,pandase,motplotlib/pandas/student.csv', sep=' ')
std
# Out:
#     first_name last_name   age  gender
# 0          Ali    Ahamdi  21.0    male
# 1   Assadullah    rahimi  22.0    male
# 2       Golsom    rahimi  19.0  female
# 3        zahra    Taheri  20.0  female
# 4        Ahamd    Rasoli   NaN    male
# 5  Rahmatullah  Jamshadi  20.0    male
# 6   Assadullah    rahimi  22.0    male

# %%
std.gender
# Out:
# 0      male
# 1      male
# 2    female
# 3    female
# Name: gender, dtype: object

# %%
std.loc[0,['first_name','last_name']]
# Out:
# first_name       Ali
# last_name     Ahamdi
# Name: 0, dtype: object

# %%
std.iloc[3,[0,3]]
# Out:
# first_name     zahra
# gender        female
# Name: 3, dtype: object

# %%
std.iloc[:,[0,3]]
# Out:
#    first_name  gender
# 0         Ali    male
# 1  Assadullah    male
# 2      Golsom  female
# 3       zahra  female

# %%
std.iloc[:,:]
# Out:
#    first_name last_name  age  gender
# 0         Ali    Ahamdi   21    male
# 1  Assadullah    rahimi   22    male
# 2      Golsom    rahimi   19  female
# 3       zahra    Taheri   20  female

# %%
std.iloc[:2,:3:2]
# Out:
#    first_name  age
# 0         Ali   21
# 1  Assadullah   22

# %%
std.isna()
# Out:
#    first_name  last_name    age  gender
# 0       False      False  False   False
# 1       False      False  False   False
# 2       False      False  False   False
# 3       False      False  False   False

# %%
std = pd.read_csv('D:/ai/numpy,pandase,motplotlib/pandas/student.csv', sep=' ')
std
# Out:
#    first_name last_name   age  gender
# 0         Ali    Ahamdi  21.0    male
# 1  Assadullah    rahimi  22.0    male
# 2      Golsom    rahimi  19.0  female
# 3       zahra    Taheri  20.0  female
# 4       Ahamd    Rasoli   NaN    male

# %%
std.isna()
# Out:
#    first_name  last_name    age  gender
# 0       False      False  False   False
# 1       False      False  False   False
# 2       False      False  False   False
# 3       False      False  False   False
# 4       False      False   True   False

# %%
std.isna().any()
# Out:
# first_name    False
# last_name     False
# age            True
# gender        False
# dtype: bool

# %%
std.isna().all()
# Out:
# first_name    False
# last_name     False
# age           False
# gender        False
# dtype: bool

# %%
std = pd.read_csv('D:/ai/numpy,pandase,motplotlib/pandas/student.csv', sep=' ')
std
# Out:
#    first_name last_name   age  gender
# 0         Ali    Ahamdi  21.0    male
# 1  Assadullah    rahimi  22.0    male
# 2      Golsom    rahimi  19.0  female
# 3       zahra    Taheri  20.0  female
# 4       Ahamd    Rasoli   NaN    male

# %%
std2 = std.dropna()
std2
# Out:
#    first_name last_name   age  gender
# 0         Ali    Ahamdi  21.0    male
# 1  Assadullah    rahimi  22.0    male
# 2      Golsom    rahimi  19.0  female
# 3       zahra    Taheri  20.0  female

# %%
std
# Out:
#    first_name last_name   age  gender
# 0         Ali    Ahamdi  21.0    male
# 1  Assadullah    rahimi  22.0    male
# 2      Golsom    rahimi  19.0  female
# 3       zahra    Taheri  20.0  female
# 4       Ahamd    Rasoli   NaN    male

# %%
std2 = std.dropna(axis=0)
std2
# Out:
#    first_name last_name   age  gender
# 0         Ali    Ahamdi  21.0    male
# 1  Assadullah    rahimi  22.0    male
# 2      Golsom    rahimi  19.0  female
# 3       zahra    Taheri  20.0  female

# %%
std.shape
# Out:
# (5, 4)

# %%
print(std.shape)
# Out:
# (5, 4)

# %%
print(std.shape,std2.shape)
# Out:
# (5, 4) (4, 4)

# %%
std
# Out:
#    first_name last_name   age  gender
# 0         Ali    Ahamdi  21.0    male
# 1  Assadullah    rahimi  22.0    male
# 2      Golsom    rahimi  19.0  female
# 3       zahra    Taheri  20.0  female

# %%
std = pd.read_csv('D:/ai/numpy,pandase,motplotlib/pandas/student.csv', sep=' ')
std
# Out:
#    first_name last_name   age  gender
# 0         Ali    Ahamdi  21.0    male
# 1  Assadullah    rahimi  22.0    male
# 2      Golsom    rahimi  19.0  female
# 3       zahra    Taheri  20.0  female
# 4       Ahamd    Rasoli   NaN    male

# %%
std.fillna(20)
# Out:
#    first_name last_name   age  gender
# 0         Ali    Ahamdi  21.0    male
# 1  Assadullah    rahimi  22.0    male
# 2      Golsom    rahimi  19.0  female
# 3       zahra    Taheri  20.0  female
# 4       Ahamd    Rasoli  20.0    male

# %%
std.gender=='male'
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# Name: gender, dtype: bool

# %%
std[std.gender=='male']
# Out:
#    first_name last_name   age gender
# 0         Ali    Ahamdi  21.0   male
# 1  Assadullah    rahimi  22.0   male
# 4       Ahamd    Rasoli   NaN   male

# %%
std[(std.gender=='male')&(std.age>20)]
# Out:
#    first_name last_name   age gender
# 0         Ali    Ahamdi  21.0   male
# 1  Assadullah    rahimi  22.0   male

# %%
std.fillna(std.mean(numeric_only=True))
# Out:
#    first_name last_name   age  gender
# 0         Ali    Ahamdi  21.0    male
# 1  Assadullah    rahimi  22.0    male
# 2      Golsom    rahimi  19.0  female
# 3       zahra    Taheri  20.0  female
# 4       Ahamd    Rasoli  20.5    male

# %%
std.max(numeric_only=True)
# Out:
# age    22.0
# dtype: float64

# %%
std
# Out:
#    first_name last_name   age  gender
# 0         Ali    Ahamdi  21.0    male
# 1  Assadullah    rahimi  22.0    male
# 2      Golsom    rahimi  19.0  female
# 3       zahra    Taheri  20.0  female
# 4       Ahamd    Rasoli   NaN    male

# %%
std1 = std.fillna(std.mode())

# %%
std1
# Out:
#    first_name last_name   age  gender
# 0         Ali    Ahamdi  21.0    male
# 1  Assadullah    rahimi  22.0    male
# 2      Golsom    rahimi  19.0  female
# 3       zahra    Taheri  20.0  female
# 4       Ahamd    Rasoli   NaN    male

# %%
std = pd.read_csv('D:/ai/numpy,pandase,motplotlib/pandas/student.csv', sep=' ')
std
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 std = pd.read_csv('D:/ai/numpy,pandase,motplotlib/pandas/student.csv', sep=' ')
#       2 std
#
# File ~\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
# ...

# %%
std1 = std.fillna(std.mode().iloc[0])
# mode().iloc[0] because there is more then one mode, each colums has its own mode

# %%
std1
# Out:
#     first_name last_name   age  gender
# 0          Ali    Ahamdi  21.0    male
# 1   Assadullah    rahimi  22.0    male
# 2       Golsom    rahimi  19.0  female
# 3        zahra    Taheri  20.0  female
# 4        Ahamd    Rasoli  20.0    male
# 5  Rahmatullah  Jamshadi  20.0    male

# %%
std.mode().iloc[0]
# Out:
# first_name     Ahamd
# last_name     rahimi
# age             20.0
# gender          male
# Name: 0, dtype: object

# %%
std.duplicated()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool

# %%
std.duplicated().any()
# Out:
# True

# %%
dp_std = pd.concat((std,std.iloc[:2]),ignore_index=True)
dp_std
# Out:
#     first_name last_name   age  gender
# 0          Ali    Ahamdi  21.0    male
# 1   Assadullah    rahimi  22.0    male
# 2       Golsom    rahimi  19.0  female
# 3        zahra    Taheri  20.0  female
# 4        Ahamd    Rasoli   NaN    male
# 5  Rahmatullah  Jamshadi  20.0    male
# 6   Assadullah    rahimi  22.0    male
# 7          Ali    Ahamdi  21.0    male
# 8   Assadullah    rahimi  22.0    male

# %%
dp_std.rename({'first_name':'firstName','last_name':'lastName','age':'Age'}, inplace=True, axis=1)

# %%
dp_std
# Out:
#      firstName  lastName   Age  gender
# 0          Ali    Ahamdi  21.0    male
# 1   Assadullah    rahimi  22.0    male
# 2       Golsom    rahimi  19.0  female
# 3        zahra    Taheri  20.0  female
# 4        Ahamd    Rasoli   NaN    male
# 5  Rahmatullah  Jamshadi  20.0    male
# 6   Assadullah    rahimi  22.0    male
# 7          Ali    Ahamdi  21.0    male
# 8   Assadullah    rahimi  22.0    male

# %%
import random

# %%
dp_std['salary'] = random.random()*100

# %%
dp_std['salary1'] = dp_std.salary.round()

# %%
dp_std
# Out:
#      firstName  lastName   Age  gender     salary  salary1
# 0          Ali    Ahamdi  21.0    male  84.271894     84.0
# 1   Assadullah    rahimi  22.0    male  84.271894     84.0
# 2       Golsom    rahimi  19.0  female  84.271894     84.0
# 3        zahra    Taheri  20.0  female  84.271894     84.0
# 4        Ahamd    Rasoli   NaN    male  84.271894     84.0
# 5  Rahmatullah  Jamshadi  20.0    male  84.271894     84.0
# 6   Assadullah    rahimi  22.0    male  84.271894     84.0
# 7          Ali    Ahamdi  21.0    male  84.271894     84.0
# 8   Assadullah    rahimi  22.0    male  84.271894     84.0

# %%
pd.Series(np.random.randint(0,10,8))
# Out:
# 0    6
# 1    6
# 2    8
# 3    5
# 4    3
# 5    4
# 6    8
# 7    7
# dtype: int32

# %%
dp_std['randin'] = pd.Series(np.random.randint(0,10,9))
dp_std
# Out:
#      firstName  lastName   Age  gender     salary  salary1  randin
# 0          Ali    Ahamdi  21.0    male  84.271894     84.0       2
# 1   Assadullah    rahimi  22.0    male  84.271894     84.0       1
# 2       Golsom    rahimi  19.0  female  84.271894     84.0       4
# 3        zahra    Taheri  20.0  female  84.271894     84.0       9
# 4        Ahamd    Rasoli   NaN    male  84.271894     84.0       7
# 5  Rahmatullah  Jamshadi  20.0    male  84.271894     84.0       9
# 6   Assadullah    rahimi  22.0    male  84.271894     84.0       0
# 7          Ali    Ahamdi  21.0    male  84.271894     84.0       4
# 8   Assadullah    rahimi  22.0    male  84.271894     84.0       5

# %%
dstd = dp_std.iloc[:4]
dstd
# Out:
#     firstName lastName   Age  gender     salary  salary1  randin
# 0         Ali   Ahamdi  21.0    male  84.271894     84.0       2
# 1  Assadullah   rahimi  22.0    male  84.271894     84.0       1
# 2      Golsom   rahimi  19.0  female  84.271894     84.0       4
# 3       zahra   Taheri  20.0  female  84.271894     84.0       9

# %%
dstd1 = pd.concat((dp_std,dstd),axis = 0,ignore_index=True)

# %%
dstd1
# Out:
#       firstName  lastName   Age  gender     salary  salary1  randin
# 0           Ali    Ahamdi  21.0    male  84.271894     84.0       2
# 1    Assadullah    rahimi  22.0    male  84.271894     84.0       1
# 2        Golsom    rahimi  19.0  female  84.271894     84.0       4
# 3         zahra    Taheri  20.0  female  84.271894     84.0       9
# 4         Ahamd    Rasoli   NaN    male  84.271894     84.0       7
# 5   Rahmatullah  Jamshadi  20.0    male  84.271894     84.0       9
# 6    Assadullah    rahimi  22.0    male  84.271894     84.0       0
# 7           Ali    Ahamdi  21.0    male  84.271894     84.0       4
# 8    Assadullah    rahimi  22.0    male  84.271894     84.0       5
# 9           Ali    Ahamdi  21.0    male  84.271894     84.0       2
# 10   Assadullah    rahimi  22.0    male  84.271894     84.0       1
# 11       Golsom    rahimi  19.0  female  84.271894     84.0       4
# 12        zahra    Taheri  20.0  female  84.271894     84.0       9

# %%
dstd1.drop(['firstName'],axis=1)
# Out:
#     lastName   Age  gender     salary  salary1  randin
# 0     Ahamdi  21.0    male  84.271894     84.0       2
# 1     rahimi  22.0    male  84.271894     84.0       1
# 2     rahimi  19.0  female  84.271894     84.0       4
# 3     Taheri  20.0  female  84.271894     84.0       9
# 4     Rasoli   NaN    male  84.271894     84.0       7
# 5   Jamshadi  20.0    male  84.271894     84.0       9
# 6     rahimi  22.0    male  84.271894     84.0       0
# 7     Ahamdi  21.0    male  84.271894     84.0       4
# 8     rahimi  22.0    male  84.271894     84.0       5
# 9     Ahamdi  21.0    male  84.271894     84.0       2
# 10    rahimi  22.0    male  84.271894     84.0       1
# 11    rahimi  19.0  female  84.271894     84.0       4
# 12    Taheri  20.0  female  84.271894     84.0       9

# %%
dstd1.drop(range(5),axis=0)
# Out:
#       firstName  lastName   Age  gender     salary  salary1  randin
# 5   Rahmatullah  Jamshadi  20.0    male  84.271894     84.0       9
# 6    Assadullah    rahimi  22.0    male  84.271894     84.0       0
# 7           Ali    Ahamdi  21.0    male  84.271894     84.0       4
# 8    Assadullah    rahimi  22.0    male  84.271894     84.0       5
# 9           Ali    Ahamdi  21.0    male  84.271894     84.0       2
# 10   Assadullah    rahimi  22.0    male  84.271894     84.0       1
# 11       Golsom    rahimi  19.0  female  84.271894     84.0       4
# 12        zahra    Taheri  20.0  female  84.271894     84.0       9

# %%
dstd1.Age
# Out:
# 0     21.0
# 1     22.0
# 2     19.0
# 3     20.0
# 4      NaN
# 5     20.0
# 6     22.0
# 7     21.0
# 8     22.0
# 9     21.0
# 10    22.0
# 11    19.0
# 12    20.0
# Name: Age, dtype: float64

# %%
dstd1.fillna(dstd1.mode().iloc[:])
# Out:
#       firstName  lastName   Age  gender     salary  salary1  randin
# 0           Ali    Ahamdi  21.0    male  84.271894     84.0       2
# 1    Assadullah    rahimi  22.0    male  84.271894     84.0       1
# 2        Golsom    rahimi  19.0  female  84.271894     84.0       4
# 3         zahra    Taheri  20.0  female  84.271894     84.0       9
# 4         Ahamd    Rasoli   NaN    male  84.271894     84.0       7
# 5   Rahmatullah  Jamshadi  20.0    male  84.271894     84.0       9
# 6    Assadullah    rahimi  22.0    male  84.271894     84.0       0
# 7           Ali    Ahamdi  21.0    male  84.271894     84.0       4
# 8    Assadullah    rahimi  22.0    male  84.271894     84.0       5
# 9           Ali    Ahamdi  21.0    male  84.271894     84.0       2
# 10   Assadullah    rahimi  22.0    male  84.271894     84.0       1
# 11       Golsom    rahimi  19.0  female  84.271894     84.0       4
# 12        zahra    Taheri  20.0  female  84.271894     84.0       9

# %%
dstd1.fillna(dstd1.mean(numeric_only=True),inplace=True)

# %%
dstd1.isna().any()
# Out:
# firstName    False
# lastName     False
# Age          False
# gender       False
# salary       False
# salary1      False
# randin       False
# dtype: bool

# %%
dstd1.Age.value_counts()
# Out:
# Age
# 22.00    4
# 21.00    3
# 20.00    3
# 19.00    2
# 20.75    1
# Name: count, dtype: int64

# %%
dstd1.isna().sum()
# Out:
# firstName    0
# lastName     0
# Age          0
# gender       0
# salary       0
# salary1      0
# randin       0
# dtype: int64

# %%
dstd1.memory_usage()
# Out:
# Index        132
# firstName    104
# lastName     104
# Age          104
# gender       104
# salary       104
# salary1      104
# randin        52
# dtype: int64

# %%
dstd1['gender1']=pd.Categorical(dstd1.gender)

# %%
dstd1
# Out:
#       firstName  lastName    Age  gender     salary  salary1  randin gender1
# 0           Ali    Ahamdi  21.00    male  84.271894     84.0       2    male
# 1    Assadullah    rahimi  22.00    male  84.271894     84.0       1    male
# 2        Golsom    rahimi  19.00  female  84.271894     84.0       4  female
# 3         zahra    Taheri  20.00  female  84.271894     84.0       9  female
# 4         Ahamd    Rasoli  20.75    male  84.271894     84.0       7    male
# 5   Rahmatullah  Jamshadi  20.00    male  84.271894     84.0       9    male
# 6    Assadullah    rahimi  22.00    male  84.271894     84.0       0    male
# 7           Ali    Ahamdi  21.00    male  84.271894     84.0       4    male
# 8    Assadullah    rahimi  22.00    male  84.271894     84.0       5    male
# 9           Ali    Ahamdi  21.00    male  84.271894     84.0       2    male
# 10   Assadullah    rahimi  22.00    male  84.271894     84.0       1    male
# ...

# %%
dstd1.memory_usage()
# Out:
# Index        132
# firstName    104
# lastName     104
# Age          104
# gender       137
# salary       104
# salary1      104
# randin        52
# gender1      137
# dtype: int64

# %%
dstd1.drop(['gender1'],axis=1,inplace=True)

# %%
dstd1
# Out:
#       firstName  lastName    Age  gender     salary  salary1  randin
# 0           Ali    Ahamdi  21.00    male  84.271894     84.0       2
# 1    Assadullah    rahimi  22.00    male  84.271894     84.0       1
# 2        Golsom    rahimi  19.00  female  84.271894     84.0       4
# 3         zahra    Taheri  20.00  female  84.271894     84.0       9
# 4         Ahamd    Rasoli  20.75    male  84.271894     84.0       7
# 5   Rahmatullah  Jamshadi  20.00    male  84.271894     84.0       9
# 6    Assadullah    rahimi  22.00    male  84.271894     84.0       0
# 7           Ali    Ahamdi  21.00    male  84.271894     84.0       4
# 8    Assadullah    rahimi  22.00    male  84.271894     84.0       5
# 9           Ali    Ahamdi  21.00    male  84.271894     84.0       2
# 10   Assadullah    rahimi  22.00    male  84.271894     84.0       1
# 11       Golsom    rahimi  19.00  female  84.271894     84.0       4
# 12        zahra    Taheri  20.00  female  84.271894     84.0       9

# %%
dstd1.memory_usage()
# Out:
# Index        132
# firstName    104
# lastName     104
# Age          104
# gender       137
# salary       104
# salary1      104
# randin        52
# dtype: int64

# %%
random.choices(['dkj','dkdk','dkdk'],k=5)
# Out:
# ['dkdk', 'dkdk', 'dkdk', 'dkdk', 'dkj']

# %%
dstd1['score']=pd.Series(random.choices(['very low','low','medium','heigh','very heigh'],k=13))

# %%
dstd1
# Out:
#       firstName  lastName    Age  gender     salary  salary1  randin  \
# 0           Ali    Ahamdi  21.00    male  84.271894     84.0       2
# 1    Assadullah    rahimi  22.00    male  84.271894     84.0       1
# 2        Golsom    rahimi  19.00  female  84.271894     84.0       4
# 3         zahra    Taheri  20.00  female  84.271894     84.0       9
# 4         Ahamd    Rasoli  20.75    male  84.271894     84.0       7
# 5   Rahmatullah  Jamshadi  20.00    male  84.271894     84.0       9
# 6    Assadullah    rahimi  22.00    male  84.271894     84.0       0
# 7           Ali    Ahamdi  21.00    male  84.271894     84.0       4
# 8    Assadullah    rahimi  22.00    male  84.271894     84.0       5
# 9           Ali    Ahamdi  21.00    male  84.271894     84.0       2
# 10   Assadullah    rahimi  22.00    male  84.271894     84.0       1
# 11       Golsom    rahimi  19.00  female  84.271894     84.0       4
# 12        zahra    Taheri  20.00  female  84.271894     84.0       9
#
# ...

# %%
dstd1.dtypes
# Out:
# firstName      object
# lastName       object
# Age           float64
# gender       category
# salary        float64
# salary1       float64
# randin          int32
# score          object
# dtype: object

# %%
dstd1['score']=pd.Categorical(dstd1.score,categories=['very low','low','medium','heigh','very heigh'],ordered=True)

# %%
sum(dstd1.score>'medium')
# Out:
# 2

# %%
dstd1['catSalary']=pd.cut(dstd1.salary,bins=[70,75,80,90,100,150],labels=['very low','low','medium','heigh','very heigh'])

# %%
dstd1
# Out:
#       firstName  lastName    Age  gender     salary  salary1  randin  \
# 0           Ali    Ahamdi  21.00    male  84.271894     84.0       2
# 1    Assadullah    rahimi  22.00    male  84.271894     84.0       1
# 2        Golsom    rahimi  19.00  female  84.271894     84.0       4
# 3         zahra    Taheri  20.00  female  84.271894     84.0       9
# 4         Ahamd    Rasoli  20.75    male  84.271894     84.0       7
# 5   Rahmatullah  Jamshadi  20.00    male  84.271894     84.0       9
# 6    Assadullah    rahimi  22.00    male  84.271894     84.0       0
# 7           Ali    Ahamdi  21.00    male  84.271894     84.0       4
# 8    Assadullah    rahimi  22.00    male  84.271894     84.0       5
# 9           Ali    Ahamdi  21.00    male  84.271894     84.0       2
# 10   Assadullah    rahimi  22.00    male  84.271894     84.0       1
# 11       Golsom    rahimi  19.00  female  84.271894     84.0       4
# 12        zahra    Taheri  20.00  female  84.271894     84.0       9
#
# ...

# %%
dstd1.memory_usage()
# Out:
# Index        132
# firstName    104
# lastName     104
# Age          104
# gender       137
# salary       104
# salary1      104
# randin        52
# score        225
# catSalary    225
# dtype: int64
