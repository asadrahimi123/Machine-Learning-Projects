# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn import metrics
from xgboost import XGBRegressor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 7
#       5 from sklearn.model_selection import train_test_split
#       6 from sklearn import metrics
# ----> 7 from xgboost import XGBRegressor
#
# ModuleNotFoundError: No module named 'xgboost'

# %%
house_price.shape
# Out:
# (506, 14)

# %%
house_price.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# PRICE      0
# dtype: int64

# %% [markdown]
# # Understanding the correlation between features in the dataset
# ### 1-Positive Correlation
# ### 1-Negative Correlation

# %%
correlation = house_price.corr()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(correlation,cbar=True,square=True,fmt='.1f',annot=True,annot_kws={'size':10},cmap='Blues')
# Out:
# <Axes: >

# %%
house_price.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
x = house_price.drop('PRICE',axis=1)
y = house_price.PRICE

# %%
x.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
y.head()
# Out:
# 0    24.0
# 1    21.6
# 2    34.7
# 3    33.4
# 4    36.2
# Name: PRICE, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)

# %%
x.shape, x_train.shape, x_test.shape
# Out:
# ((506, 13), (404, 13), (102, 13))

# %% [markdown]
# ## Model Training

# %%
model = XGBRegressor()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 model = XGBRegressor()
#
# NameError: name 'XGBRegressor' is not defined

# %%
model.fit(x_train, y_train)

# %%
# Model Evaluation

# %%
x_train_pre = model.predict(x_train)

# %%
score1 = metrics.r2_score(y_train, x_train_pre)
score2 = metrics.mean_absolute_error(y_train, x_train_pre)
print('R squared error')
print('Mean Absolute error')

# %%
plt.scatter(y_train, x_train_pre)
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual Price V Predicted Prcie')

# %%
x_test_pre = model.predcit(x_test)
score1 = metrics.re2_score(y_test, x_test_pre)
score1 = metrics.re2_score(y_test, x_test_pre)
